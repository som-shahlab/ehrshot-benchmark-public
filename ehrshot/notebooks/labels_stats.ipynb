# %%
import pandas as pd
from tqdm import tqdm
import os
from typing import List, Dict

# %%
# Same ordering as paper
task_2_name: Dict[str, str] = {
    # Operational outcomes
    'longlos': 'Long LOS',
    '30dayreadmit': '30-Day Readmission',
    'icuadmit': 'ICU Admission',
    # Anticipating lab test results
    'thrombocytopenia': 'Thrombocytopenia',
    'hyperkalemia': 'Hyperkalemia',
    'hypoglycemia': 'Hypoglycemia',
    'hyponatremia': 'Hyponatremia',
    'anemia': 'Anemia',
    # Assignment of new diagnoses
    'hypertension': 'Hypertension',
    'hyperlipidemia': 'Hyperlipidemia',
    'pancan': 'Pancreatic Cancer',
    'celiac': 'Celiac',
    'lupus': 'Lupus',
    'ami' : 'Acute MI',
    # Anticipating chest x-ray findings
    'chexpert' : 'Chest X-Ray',
}

task_2_value_type: Dict[str, str] = {
    'pancan': 'boolean',
    'celiac': 'boolean',
    'lupus': 'boolean',
    'ami' : 'boolean',
    'hypertension': 'boolean',
    'hyperlipidemia': 'boolean',
    'longlos': 'boolean',
    '30dayreadmit': 'boolean',
    'icuadmit': 'boolean',
    'thrombocytopenia': 'multiclass',
    'hyperkalemia': 'multiclass',
    'hypoglycemia': 'multiclass',
    'hyponatremia': 'multiclass',
    'anemia': 'multiclass',
    'chexpert' : 'multilabel',
}

# %%
path_to_splits = '/Users/mwornow/Downloads/som-nero-nigam-starr.starr_omop_cdm5_confidential_filtered_2024_02_12_ehrshot_release_dua/person_id_map/merged.csv'
df_splits = pd.read_csv(path_to_splits)
df_splits.shape
# Out:
# (6732, 2)

# %% [markdown]
# # Get label counts for each task
#
# Do split by train/test/val

# %%
results = {
    'train' : [],
    'test' : [],
    'val' : [],
    'all' : []
}
for task, task_name in tqdm(task_2_name.items()):
    if not os.path.exists(f"./{task}_labels.csv"):
        print(f"Skipping {task_name}")
        continue
    df = pd.read_csv(f"./{task}_labels.csv")
    if task_2_value_type[task] == "boolean":
        df['is_positive_label'] = df["boolean_value"]      
    elif task_2_value_type[task] == "multiclass":
        df['is_positive_label'] = df["integer_value"] > 0
    else:
        print(f"Skipping {task_name}")
        continue
    
    # Splits
    for split in ['train', 'test', 'val']:
        df_split = df[df['patient_id'].isin(df_splits[df_splits['split'] == split]['omop_person_id'])]
        results[split].append({
            'task' : task,
            'task_name' : task_name,
            'n_patients' : df_split['patient_id'].nunique(),
            'n_positive_patients' : df_split.groupby('patient_id')['is_positive_label'].max().sum(),
            'n_labels' : df_split.shape[0],
            'n_positive_labels' : df_split['is_positive_label'].sum(),
        })
    
    # All
    results['all'].append({
        'task' : task,
        'task_name' : task_name,
        'n_patients' : df['patient_id'].nunique(),
        'n_positive_patients' : df.groupby('patient_id')['is_positive_label'].max().sum(),
        'n_labels' : df.shape[0],
        'n_positive_labels' : df['is_positive_label'].sum(),
    })

for key in results.keys():
    results[key] = pd.DataFrame(results[key])
    results[key]['n_negative_labels'] = results[key]['n_labels'] - results[key]['n_positive_labels']
    results[key]['n_negative_patients'] = results[key]['n_patients'] - results[key]['n_positive_patients']
    results[key]['label_prevalence'] = results[key]['n_positive_labels'] / results[key]['n_labels']
# Out:
# 100%|██████████| 15/15 [00:01<00:00, 14.53it/s]
# Skipping Chest X-Ray

# %%
# All splits
results['all']
# Out:
#                 task           task_name  n_patients  n_positive_patients  \
# 0            longlos            Long LOS        4636                 1772
# 1       30dayreadmit  30-Day Readmission        4777                 2363
# 2           icuadmit       ICU Admission        4421                  587
# 3   thrombocytopenia    Thrombocytopenia        6076                 2605
# 4       hyperkalemia        Hyperkalemia        5948                 1310
# 5       hypoglycemia        Hypoglycemia        5993                 1422
# 6       hyponatremia        Hyponatremia        5937                 3735
# 7             anemia              Anemia        6096                 4308
# 8       hypertension        Hypertension        2829                  747
# 9     hyperlipidemia      Hyperlipidemia        3250                  810
# 10            pancan   Pancreatic Cancer        4292                  215
# 11            celiac              Celiac        4315                   74
# 12             lupus               Lupus        4286                  135
# 13               ami            Acute MI        4279                  474
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0      14723               3286              11437                 2864
# 1      32725              17327              15398                 2414
# 2      13915                713              13202                 3834
# 3     206099              66168             139931                 3471
# 4     234290               5535             228755                 4638
# 5     356066               5431             350635                 4571
# 6     252578              71111             181467                 2202
# 7     214483             147625              66858                 1788
# 8      12452               3232               9220                 2082
# 9      16213               3703              12510                 2440
# 10     28552                769              27783                 4077
# 11     28932                475              28457                 4241
# 12     27732                540              27192                 4151
# 13     26066               3405              22661                 3805
#
#     label_prevalence
# 0           0.223188
# 1           0.529473
# 2           0.051240
# 3           0.321050
# 4           0.023625
# 5           0.015253
# 6           0.281541
# 7           0.688283
# 8           0.259557
# 9           0.228397
# 10          0.026933
# 11          0.016418
# 12          0.019472
# 13          0.130630

# %%
# Train
results['train']
# Out:
#                 task           task_name  n_patients  n_positive_patients  \
# 0            longlos            Long LOS        1620                  645
# 1       30dayreadmit  30-Day Readmission        1674                  850
# 2           icuadmit       ICU Admission        1560                  228
# 3   thrombocytopenia    Thrombocytopenia        2090                  922
# 4       hyperkalemia        Hyperkalemia        2046                  469
# 5       hypoglycemia        Hypoglycemia        2063                  528
# 6       hyponatremia        Hyponatremia        2043                 1310
# 7             anemia              Anemia        2096                 1495
# 8       hypertension        Hypertension         955                  258
# 9     hyperlipidemia      Hyperlipidemia        1118                  279
# 10            pancan   Pancreatic Cancer        1494                  127
# 11            celiac              Celiac        1508                   51
# 12             lupus               Lupus        1496                   83
# 13               ami            Acute MI        1495                  164
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       5562               1267               4295                  975
# 1      12302               6628               5674                  824
# 2       5298                271               5027                 1332
# 3      79303              24989              54314                 1168
# 4      89381               2202              87179                 1577
# 5     135600               2123             133477                 1535
# 6      96298              27665              68633                  733
# 7      81941              56961              24980                  601
# 8       4158               1055               3103                  697
# 9       6044               1242               4802                  839
# 10     10434                390              10044                 1367
# 11     10644                162              10482                 1457
# 12     10023                317               9706                 1413
# 13      9508               1251               8257                 1331
#
#     label_prevalence
# 0           0.227796
# 1           0.538774
# 2           0.051151
# 3           0.315108
# 4           0.024636
# 5           0.015656
# 6           0.287285
# 7           0.695147
# 8           0.253728
# 9           0.205493
# 10          0.037378
# 11          0.015220
# 12          0.031627
# 13          0.131573

# %%
# Val
results['val']
# Out:
#                 task           task_name  n_patients  n_positive_patients  \
# 0            longlos            Long LOS        1511                  548
# 1       30dayreadmit  30-Day Readmission        1556                  758
# 2           icuadmit       ICU Admission        1427                  178
# 3   thrombocytopenia    Thrombocytopenia        1983                  814
# 4       hyperkalemia        Hyperkalemia        1940                  430
# 5       hypoglycemia        Hypoglycemia        1957                  437
# 6       hyponatremia        Hyponatremia        1935                 1186
# 7             anemia              Anemia        1993                 1394
# 8       hypertension        Hypertension         940                  241
# 9     hyperlipidemia      Hyperlipidemia        1058                  270
# 10            pancan   Pancreatic Cancer        1399                   45
# 11            celiac              Celiac        1404                    8
# 12             lupus               Lupus        1393                   31
# 13               ami            Acute MI        1388                  151
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       4440                979               3461                  963
# 1      10251               5447               4804                  798
# 2       4167                221               3946                 1249
# 3      61955              19712              42243                 1169
# 4      69919               1566              68353                 1510
# 5     107605               1758             105847                 1520
# 6      75961              20541              55420                  749
# 7      64634              43992              20642                  599
# 8       4246               1104               3142                  699
# 9       5173               1189               3984                  788
# 10      9276                134               9142                 1354
# 11      9493                231               9262                 1396
# 12      8999                182               8817                 1362
# 13      8498               1084               7414                 1237
#
#     label_prevalence
# 0           0.220495
# 1           0.531363
# 2           0.053036
# 3           0.318166
# 4           0.022397
# 5           0.016338
# 6           0.270415
# 7           0.680632
# 8           0.260009
# 9           0.229847
# 10          0.014446
# 11          0.024334
# 12          0.020224
# 13          0.127559

# %%
# Test
results['test']
# Out:
#                 task           task_name  n_patients  n_positive_patients  \
# 0            longlos            Long LOS        1505                  579
# 1       30dayreadmit  30-Day Readmission        1547                  755
# 2           icuadmit       ICU Admission        1434                  181
# 3   thrombocytopenia    Thrombocytopenia        2003                  869
# 4       hyperkalemia        Hyperkalemia        1962                  411
# 5       hypoglycemia        Hypoglycemia        1973                  457
# 6       hyponatremia        Hyponatremia        1959                 1239
# 7             anemia              Anemia        2007                 1419
# 8       hypertension        Hypertension         934                  248
# 9     hyperlipidemia      Hyperlipidemia        1074                  261
# 10            pancan   Pancreatic Cancer        1399                   43
# 11            celiac              Celiac        1403                   15
# 12             lupus               Lupus        1397                   21
# 13               ami            Acute MI        1396                  159
#
#     n_labels  n_positive_labels  n_negative_labels  n_negative_patients  \
# 0       4721               1040               3681                  926
# 1      10172               5252               4920                  792
# 2       4450                221               4229                 1253
# 3      64841              21467              43374                 1134
# 4      74990               1767              73223                 1551
# 5     112861               1550             111311                 1516
# 6      80319              22905              57414                  720
# 7      67908              46672              21236                  588
# 8       4048               1073               2975                  686
# 9       4996               1272               3724                  813
# 10      8842                245               8597                 1356
# 11      8795                 82               8713                 1388
# 12      8710                 41               8669                 1376
# 13      8060               1070               6990                 1237
#
#     label_prevalence
# 0           0.220292
# 1           0.516319
# 2           0.049663
# 3           0.331071
# 4           0.023563
# 5           0.013734
# 6           0.285175
# 7           0.687283
# 8           0.265069
# 9           0.254604
# 10          0.027709
# 11          0.009323
# 12          0.004707
# 13          0.132754
